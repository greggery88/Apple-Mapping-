# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv("/Users/jwilliamson/git/plasma_particle_simulator/Apple-mapping/csv/reformated_data.csv", keep_default_na=False)
df
# Out:
#          County       Fair  Year  IsApple                 Given_ID  \
# 0          Knox   Knox Co.  1867    False          (Pear) Barltett
# 1          Knox   Knox Co.  1867    False    (Pear) Bell Lucrative
# 2          Knox   Knox Co.  1867    False       (Pear) Beurre Bosc
# 3          Knox   Knox Co.  1867    False  (Pear) Beurre Clairgeau
# 4          Knox   Knox Co.  1867    False      (Pear) Beurre Hardy
# ...         ...        ...   ...      ...                      ...
# 112861  Lincoln  Nobleboro  1921     True             Sweet Russet
# 112862  Lincoln  Nobleboro  1921     True             Tolman sweet
# 112863  Lincoln  Nobleboro  1921     True                  Wealthy
# 112864  Lincoln  Nobleboro  1921     True               Wolf River
# 112865  Lincoln  Nobleboro  1921     True            York Imperial
#
#           Given_ID_Clean Alt_ID Alt_ID_Clean Presumed_ID Presumed_ID_Clean  \
# 0               barltett
# 1         bell lucrative
# 2            beurre bosc
# ...

# %%
gf = df.drop(columns=["County", 'Fair', 'Year', "Alt_ID", 'Uncertain'])

# %%
data =df[['Given_ID_Clean', 'Presumed_ID_Clean']].drop_duplicates()
data.to_csv("/Users/jwilliamson/git/plasma_particle_simulator/Apple-mapping/csv/Presumed_ID_key.csv", index=False)

# %%
gf.to_csv(f"{os.getcwd()}/Presumed.csv", index=False)

# %%
pf = pd.read_csv("/Users/jwilliamson/git/plasma_particle_simulator/Apple-mapping/csv/Presumed_ID_key.csv")
pf.drop_duplicates()
nf = df.merge(pf, how="left", on="Given_ID")
nf
# Out:
#         County       Fair  Year               Given_ID Alt_ID Presumed_ID_x  \
# 0         Knox   Knox Co.  1867               pearmain    NaN           NaN
# 1         Knox   Knox Co.  1867               pearmain    NaN           NaN
# 2         Knox   Knox Co.  1867                 porter    NaN        porter
# 3         Knox   Knox Co.  1867                 porter    NaN        porter
# 4         Knox   Knox Co.  1869  (pear) flemish beauty    NaN           NaN
# ...        ...        ...   ...                    ...    ...           ...
# 51504  Lincoln  Nobleboro  1921                wealthy    NaN           NaN
# 51505  Lincoln  Nobleboro  1921                wealthy    NaN           NaN
# 51506  Lincoln  Nobleboro  1921             wolf river    NaN           NaN
# 51507  Lincoln  Nobleboro  1921             wolf river    NaN           NaN
# 51508  Lincoln  Nobleboro  1921          york imperial    NaN           NaN
#
#        Uncertain  Presumed_ID_y
# ...

# %%
pf = pd.read_csv("/Users/jwilliamson/git/plasma_particle_simulator/Apple-mapping/csv/Presumed_ID_key.csv")
pf = pf.drop_duplicates()
dup_s = pf.duplicated(subset=["Given_ID"], keep=False)
dup_s.value_counts()
# Out:
# False    1964
# True      643
# Name: count, dtype: int64

# %%
pf = pd.read_csv("/Users/jwilliamson/git/plasma_particle_simulator/Apple-mapping/csv/Presumed_ID_key.csv")
pf = pf.drop_duplicates()
pf.to_csv("/Users/jwilliamson/git/plasma_particle_simulator/Apple-mapping/csv/Presumed_ID_key.csv", index=False)
